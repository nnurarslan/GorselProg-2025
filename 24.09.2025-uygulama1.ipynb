# %%
'''
Bu bir
çoklu 
yorum satırı
'''
print("hello world!") #Bu bir yorum satırı
# Out:
# hello world!

# %%
print("hello\nworld!") #yeni satır
# Out:
# hello
# world!

# %%
print("hello\tworld!") #tab boslugu
# Out:
# hello	world!

# %%
print("birinci satir", end =" ")
print("ikinci satir")
# Out:
# birinci satir ikinci satir

# %%
print("ilk satir")
print()
print("ikinci satir")
# Out:
# ilk satir
#
# ikinci satir

# %%
print("Python " * 5)
# Out:
# Python Python Python Python Python

# %%
str1 = "Python"
print(len(str1))
# Out:
# 6

# %%
myvar = "John"
my_var = "John"
_my_var = "john"
myVar = "John"
MYVAR = "John"
myvar2 = "John"

# %%
2mayvar = "John"
# Out:
#   Cell In[15], line 1
#     2mayvar = "John"
#     ^
# SyntaxError: invalid decimal literal

# %%
my-var = "john"
# Out:
#   Cell In[16], line 1
#     my-var = "john"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
my var = "john"
# Out:
#   Cell In[17], line 1
#     my var = "john"
#        ^
# SyntaxError: invalid syntax

# %%
print("Java", "Python", "C++", sep = ",")
# Out:
# Java,Python,C++

# %%
print("It's alright")
# Out:
# It's alright

# %%
print('He is called "Johny"')
# Out:
# He is called "Johny"

# %%
b = "Hello World!"
print(b[0])
# Out:
# H

# %%
print(b[-1])
# Out:
# !

# %%
print(b[2:4])
# Out:
# ll

# %%
print(b[2:])
# Out:
# llo World!

# %%
print(b[-5:-2])
# Out:
# orl

# %%
c = "Python Prog"

# %%
print(c[2:8])
# Out:
# thon P

# %%
print(c.upper())
# Out:
# PYTHON PROG

# %%
print(c.lower())
# Out:
# python prog

# %%
d = "hello"

# %%
print(d.capitalize())
# Out:
# Hello

# %%
e = "  Hello world! "

# %%
print(e.strip())
# Out:
# Hello world!

# %%
f = "Python Programlama"

# %%
f.find("Programlama")
# Out:
# 7

# %%
f.count("a")
# Out:
# 3

# %%
g = "Hello World"

# %%
print(g.replace("H","J"))
# Out:
# Jello World

# %%
h = "Hello,World"

# %%
h.split(",")
# Out:
# ['Hello', 'World']

# %%
a = "hello"

# %%
b = "world"

# %%
print(a,b)
# Out:
# hello world

# %%
age = 36
txt = "My name is John, I am" + age
print(txt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 2
#       1 age = 36
# ----> 2 txt = "My name is John, I am" + age
#       3 print(txt)
#
# TypeError: can only concatenate str (not "int") to str

# %%
txt = f"My name is John, I am {age}"
print(txt)
# Out:
# My name is John, I am 36

# %%
txt = f"The price is {2*3} dollars"
print(txt)
# Out:
# The price is 6 dollars

# %%
print(10>9)
# Out:
# True

# %%
print(10<9)
# Out:
# False

# %%
str1 = "Python Prog"

# %%
print(str1.startswith("Py"))
# Out:
# True

# %%
print(str1.endswith("Py"))
# Out:
# False

# %%
print("Java" in str1)
# Out:
# False

# %%
x = str(3)
y = int(3)
z = float(3)
print(x)
print(y)
print(z)
# Out:
# 3
# 3
# 3.0

# %%
isim = "Ali"
yas = 29
print("İsim:", isim, "yas :", yas)
# Out:
# İsim: Ali yas : 29

# %%
a,b,c = 5, 10 , 15
print(a,b,c)
# Out:
# 5 10 15

# %%
print(c)
# Out:
# 15

# %%
x=y=z ="orange"
print(x)
# Out:
# orange

# %%
x=5
y=10
print(x+y)
# Out:
# 15

# %%
x=5
y="john"
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 3
#       1 x=5
#       2 y="john"
# ----> 3 print(x+y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x="5"
y="john"
print(x+y)
# Out:
# 5john

# %%
x=5
y="john"
print(x,y)
# Out:
# 5 john

# %%
isim
yas
boy
medeni_hal
bu bilgileri değişken ataması yapıp ekrana yazdırın

# %%
isim ="Nur"
yas = 29
boy = 1.60
medeni_hal = True
print("Yas:", yas)
# Out:
# Yas: 29

# %%
print(type(medeni_hal))
# Out:
# <class 'bool'>

# %%
yas = 25
print("Yaşınız" + ' ' + str(yas))
# Out:
# Yaşınız 25

# %%
adres = """Ankara
Çankaya
Kızılay
"""
print(adres)
# Out:
# Ankara
# Çankaya
# Kızılay

# %%
print(5 + 4 - 7 + 3)
# Out:
# 5

# %%
print(100 + 5 * 3)
# Out:
# 115

# %%
sonuc = None
print("Sonuc : ", sonuc)
# Out:
# Sonuc :  None

# %%
sonuc = 42
print("Yeni sonuc : ", sonuc)
# Out:
# Yeni sonuc :  42

# %%
a = 17
b = 4
Toplam, fark, carpim, bolme, mod alma, tam sayı bolme, üs alma islemlerini 
yapıp ekrana sonuçları basın

# %%
toplam = a + b
fark = a - b
carpim = a * b
bolme = a / b
mod = a % b
tamsbolme = a // b
usalma = a ** b
print(toplam, fark , usalma)
# Out:
# 15 -5 9765625

# %%
import math
sayi = 16
karekok = math.sqrt(sayi)
print(karekok)
# Out:
# 4.0

# %%
sayi = -15
print(abs(sayi))
# Out:
# 15

# %%
sayi = 5
print(math.factorial(sayi))
# Out:
# 120

# %%
import random
rastgele_sayi = random.randint(1,100)
print(rastgele_sayi)
# Out:
# 83

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
sayi1 = 5
sayi2 = 10
sayi3 = 15
enbuyuk = max(sayi1,sayi2,sayi3)
print(enbuyuk)
# Out:
# 15

# %%
enkucuk = min(sayi1,sayi2,sayi3)
print(enkucuk)
# Out:
# 5

# %%
sayi = 7 / 3
print(sayi)
# Out:
# 2.3333333333333335

# %%
yuvarlanmis = round(sayi,2)
print(yuvarlanmis)
# Out:
# 2.33

# %%
sayi = input("Sayi giriniz ")
# Out:
# Sayi giriniz 5

# %%
print(sayi)
# Out:
# 5

# %%
1-Kullanicidan sehir ismi isteyin
2-Bu sehirin harflerini buyuk yapin
3-Sehir isminin ilk ve son harflerini yazdirin
4-Sehir isminin uzunlugunu ekrana yazdirin
5-Kullanicidan uc sayi alin
6-bu sayilarin ortalamasini bulun ondalikli olsun virgulden sonra 
  3 basamak gozuksun
