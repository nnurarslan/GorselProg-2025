# %% [markdown]
# # LİST

# %%
bos_liste = []

# %%
print(type(bos_liste))
# Out:
# <class 'list'>

# %%
meyveler = ["elma", "armut", "kivi", "muz"]

# %%
print(meyveler)
# Out:
# ['elma', 'armut', 'kivi', 'muz']

# %%
#Listeye eleman ekleme
meyveler.append("cilek")

# %%
meyveler
# Out:
# ['elma', 'armut', 'kivi', 'muz', 'cilek']

# %%
meyveler.insert(2,"seftali")

# %%
meyveler
# Out:
# ['elma', 'armut', 'seftali', 'kivi', 'muz', 'cilek']

# %%
yeni_meyveler = ["kavun","karpuz"]
meyveler.extend(yeni_meyveler)

# %%
meyveler
# Out:
# ['elma', 'armut', 'seftali', 'kivi', 'muz', 'cilek', 'kavun', 'karpuz']

# %%
yeni = ["ejder_meyvesi"]
print(meyveler+yeni)
# Out:
# ['elma', 'armut', 'seftali', 'kivi', 'muz', 'cilek', 'kavun', 'karpuz', 'ejder_meyvesi']

# %%
meyveler
# Out:
# ['elma', 'armut', 'seftali', 'kivi', 'muz', 'cilek', 'kavun', 'karpuz']

# %%
meyveler = meyveler + yeni

# %%
print(meyveler[2])
# Out:
# seftali

# %%
print(meyveler[-1])
# Out:
# ejder_meyvesi

# %%
print(meyveler[2:5])
# Out:
# ['seftali', 'kivi', 'muz']

# %%
print(meyveler)
# Out:
# ['elma', 'armut', 'seftali', 'kivi', 'muz', 'cilek', 'kavun', 'karpuz', 'ejder_meyvesi']

# %%
print(meyveler[2:])
# Out:
# ['seftali', 'kivi', 'muz', 'cilek', 'kavun', 'karpuz', 'ejder_meyvesi']

# %%
print(meyveler[-3:-1])
# Out:
# ['kavun', 'karpuz']

# %%
meyveler[1] = "greyfurt"

# %%
print(meyveler)
# Out:
# ['elma', 'greyfurt', 'seftali', 'kivi', 'muz', 'cilek', 'kavun', 'karpuz', 'ejder_meyvesi']

# %%
meyveler.remove("seftali")

# %%
meyveler
# Out:
# ['elma',
#  'greyfurt',
#  'kivi',
#  'muz',
#  'cilek',
#  'kavun',
#  'karpuz',
#  'ejder_meyvesi']

# %%
meyveler.pop()
# Out:
# 'ejder_meyvesi'

# %%
meyveler
# Out:
# ['elma', 'greyfurt', 'kivi', 'muz', 'cilek', 'kavun', 'karpuz']

# %%
meyveler.clear()

# %%
meyveler
# Out:
# []

# %%
my_list = [1,2,3,4,5]

# %%
print(my_list[::2])
# Out:
# [1, 3, 5]

# %%
print(len(my_list))
# Out:
# 5

# %%
my_list = [1,2,3,4,5,2,2]

# %%
print(my_list.count(2))
# Out:
# 3

# %%
print(my_list.index(2))
# Out:
# 1

# %%
my_list.sort()

# %%
print(my_list)
# Out:
# [1, 2, 2, 2, 3, 4, 5]

# %%
meyve = ['elma', 'greyfurt', 'seftali', 'kivi', 'muz', 'cilek', 'kavun', 'karpuz', 'ejder_meyvesi']

# %%
meyve.sort()

# %%
print(meyve)
# Out:
# ['cilek', 'ejder_meyvesi', 'elma', 'greyfurt', 'karpuz', 'kavun', 'kivi', 'muz', 'seftali']

# %%
meyve.sort(reverse=True)

# %%
print(meyve)
# Out:
# ['seftali', 'muz', 'kivi', 'kavun', 'karpuz', 'greyfurt', 'elma', 'ejder_meyvesi', 'cilek']

# %%
meyve.reverse()

# %%
print(meyve)
# Out:
# ['cilek', 'ejder_meyvesi', 'elma', 'greyfurt', 'karpuz', 'kavun', 'kivi', 'muz', 'seftali']

# %%
kopya_meyveler = meyve.copy()

# %%
print(kopya_meyveler)
# Out:
# ['elma', 'greyfurt', 'seftali', 'kivi', 'muz', 'cilek', 'kavun', 'karpuz', 'ejder_meyvesi']

# %%
kopya_meyveler = meyve[:]

# %% [markdown]
# # Dictionary

# %%
kisi_bilgileri = {
    "ad" : "Nur",
    "meslek" : "muhendis",
    "yas" : 29
}

# %%
print(kisi_bilgileri["yas"])
# Out:
# 29

# %%
kisi_bilgileri["sehir"] = "Kutahya"

# %%
print(kisi_bilgileri)
# Out:
# {'ad': 'Nur', 'meslek': 'muhendis', 'yas': 29, 'sehir': 'Kutahya'}

# %%
del kisi_bilgileri["meslek"]

# %%
print(kisi_bilgileri)
# Out:
# {'ad': 'Nur', 'yas': 29, 'sehir': 'Kutahya'}

# %%
print(kisi_bilgileri.keys())
# Out:
# dict_keys(['ad', 'yas', 'sehir'])

# %%
print(kisi_bilgileri.values())
# Out:
# dict_values(['Nur', 29, 'Kutahya'])

# %%
print(kisi_bilgileri.items())
# Out:
# dict_items([('ad', 'Nur'), ('yas', 29), ('sehir', 'Kutahya')])

# %%
kisiler = {
    "kisi_1" : {
        "ad" : "ayse",
        "yas": 26
    },
    "kisi_2": {
        "ad" : "ahmet",
        "yas": 27

    }
}

# %%
print(kisiler["kisi_2"]["yas"])
# Out:
# 27

# %%
print(kisiler["kisi_1"]["ad"])
# Out:
# ayse

# %% [markdown]
# # TUPLE

# %%
my_tuple= (1,2,3,4)

# %%
single_element_tuple = (5,)

# %%
my_tuple[1:3]
# Out:
# (2, 3)

# %%
print(sum(my_tuple))
# Out:
# 10

# %%
print(min(my_tuple))
# Out:
# 1

# %%
print(max(my_tuple))
# Out:
# 4

# %%
tuple1 = (1,2)

# %%
tuple2 = (3,4)

# %%
result = tuple1 + tuple2

# %%
print(result)
# Out:
# (1, 2, 3, 4)

# %%
print(5 in result)
# Out:
# False

# %%
print(len(result))
# Out:
# 4

# %%
result
# Out:
# (1, 2, 3, 4)

# %%
print(type(result))
# Out:
# <class 'tuple'>

# %%
result[1] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 result[1] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_tuple = (1, 2, 3, 4)

# %%
my_list = list(my_tuple)

# %%
my_list[1] = 20

# %%
my_list
# Out:
# [1, 20, 3, 4]

# %%
my_tuple = tuple(my_list)

# %%
my_tuple
# Out:
# (1, 20, 3, 4)

# %%
my_tuple = (10,20,30,40)

# %%
my_listt = list(my_tuple)

# %%
my_listt.remove(20)

# %%
my_listt.append(30)

# %%
my_tuple = tuple(my_listt)

# %%
my_tuple
# Out:
# (10, 30, 40, 30)

# %%
my_tuple = (1,2,3)

# %%
a,b,c = my_tuple

# %%
a
# Out:
# 1

# %%
my_tuple = (1,2,3,4,5)

# %%
a,b, *rest = my_tuple

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
rest
# Out:
# [3, 4, 5]

# %%
my_tuple = (1,2,3,4,5)

# %%
a, *middle, d, e = my_tuple

# %%
a
# Out:
# 1

# %%
d
# Out:
# 4

# %%
e
# Out:
# 5

# %%
middle
# Out:
# [2, 3]

# %% [markdown]
# # SET

# %%
my_set = {1,2,3}

# %%
my_set.add(4)

# %%
my_set
# Out:
# {1, 2, 3, 4}

# %%
my_set.add(4)

# %%
my_set
# Out:
# {1, 2, 3, 4}

# %%
my_set.remove(3)

# %%
my_set
# Out:
# {1, 2, 4}

# %%
my_set.remove(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 my_set.remove(5)
#
# KeyError: 5

# %%
my_set.discard(5)

# %%
my_set.pop()
# Out:
# 1

# %%
my_set
# Out:
# {2, 4}

# %%
my_set.clear()

# %%
my_set
# Out:
# set()

# %%
set1 = {1,2,3,4}

# %%
set2 = {3,4,5,6}

# %%
print(set1.union(set2))
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
print(set1 | set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
print(set1.intersection(set2))
# Out:
# {3, 4}

# %%
print(set1 & set2)
# Out:
# {3, 4}

# %%
print(set1.difference(set2))
# Out:
# {1, 2}

# %%
print(set1 - set2)
# Out:
# {1, 2}

# %%
ogrenciler isminde dictionary oluşturun
2 tane öğrenci ekleyin
ad,yas,notlar,dersler,gezdigi_yerler
notlar list
dersler set
gezdigi_yerler tuple
** Bir öğrencinin adını yazdırın
** Bir öğrencinin not ortalamasını bulun
** Bir öğrencinin dersine yeni ders ekleyin
** bu iki öğrencinin ortak derslerini bulun
** ikinci öğrencinin son gezdigi yeri bulun
