# %%
def merhaba():
    print("merhaba dünya")
merhaba()
merhaba()
merhaba()
# Out:
# merhaba dünya
# merhaba dünya
# merhaba dünya

# %%
def toplam(a, b):
    return a+b
sonuc = toplam(5,10)
print(sonuc)
# Out:
# 15

# %%
m1 = 5
cm1 = m1 * 100
print(cm1)

m1 = 10
cm1 = m1 * 100
print(cm1)

m1 = 15
cm1 = m1 * 100
print(cm1)
# Out:
# 500
# 1000
# 1500

# %%
def metre_to_cm(metre):
    cm = metre * 100
    return cm
print(metre_to_cm(5))
print(metre_to_cm(15))
print(metre_to_cm(25))
# Out:
# 500
# 1500
# 2500

# %%
def func(fname,lname):
    print(fname + " " + lname)
func("Nur","Arslan")
# Out:
# Nur Arslan

# %%
def func(fname,lname="ARSLAN"):
    print(fname + " " + lname)
func("Nur")
# Out:
# Nur ARSLAN

# %%
def bilgiler(isim, yas, sehir):
    print(f"İsim : {isim}, Yaş : {yas}, Şehir: {sehir}")
bilgiler(sehir="Kutahya", isim="Nur", yas=29)
# Out:
# İsim : Nur, Yaş : 29, Şehir: Kutahya

# %%
def toplama(*args):
    return sum(args)
print(toplama(1,2,3,4))

def kisi_bilgileri(**kwargs):
    for key,value in kwargs.items():
        print(f"{key}:{value}")
kisi_bilgileri(isim="mehmet",yas=28,sehir="istanbul")
# Out:
# 10
# isim:mehmet
# yas:28
# sehir:istanbul

# %%
x=30
def func():
    x=20
    print(x)
func()
print(x)
# Out:
# 20
# 30

# %%
x=30
def func():
    global x
    x=20
    print(x)
func()
print(x)
# Out:
# 20
# 20

# %%
def func():
    y=20
    print(y)
func()
print(y)
# Out:
# 20
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 5
#       3     print(y)
#       4 func()
# ----> 5 print(y)
#
# NameError: name 'y' is not defined

# %%
def func():
    y=20
    def inner_func():
        print(y)
    inner_func()
func()
# Out:
# 20

# %%
kur=34.5
def scope_ornegi():
    global kur
    print("mevcut kur",kur)
    kur=35.0
    print("Yeni kur",kur)
scope_ornegi()
print(kur)
def ana_program():
    giris = input("Dolar miktarlarını boslukla ayırarak gir")
    #10 20 30 40 
    miktarlar = [float(x) for x in giris.split()]
    print(miktarlar)
    tl_sonuclari = dolar_to_tl(*miktarlar)
    ozet_bilgi(islem="Doviz Donusumu",
              adet = len(tl_sonuclari),
              toplam = sum(tl_sonuclari))
# Out:
# mevcut kur 34.5
# Yeni kur 35.0
# 35.0

# %%
def dolar_to_tl(*dolar_miktarlari):
    tl_listesi = []
    for d in dolar_miktarlari:
        tl = d * kur
        tl_listesi.append(tl)
        print(f"{d} dolar = {tl} TL")
    return tl_listesi

# %%
def ozet_bilgi(**bilgiler):
    for anahtar,deger in bilgiler.items():
        print(f"{anahtar.capitalize()} : {deger}")

# %%
ana_program()
# Out:
# Dolar miktarlarını boslukla ayırarak gir10 20 30 40
# [10.0, 20.0, 30.0, 40.0]
# 10.0 dolar = 350.0 TL
# 20.0 dolar = 700.0 TL
# 30.0 dolar = 1050.0 TL
# 40.0 dolar = 1400.0 TL
# Islem : Doviz Donusumu
# Adet : 4
# Toplam : 3500.0

# %%
Hangi geometrik şeklin alanını ve çevresini hesaplamak istiyorsunuz?
1. Dikdörtgen
2. Daire 
3. Kare
Seçiminizi yapın (1/2/3):
Dikdörtgen, kare, daire ayrı fonksiyonlarda alan hesabı yapılsın
Dikdörtgen, kare, daire ayrı fonksiyonlarda cevre hesabı yapılsın

# %%
if __name__ == "__main__":
    main()
# Out:
# 1. Dikdörtgen, 2. Daire, 3. Kare
# Seçiminizi yapın 1,2,31
# Kısa kenar : 2
# Uzun kenar : 5
# 10.0

# %%
import math

# %%
def main():
    # Bu fonksiyon kullanıcıdan secim alarak ilgili fonksiyonları çağırır
    # ekrana cevre alan hesabını yazdırır
    print("1. Dikdörtgen, 2. Daire, 3. Kare")
    secim = int(input("Seçiminizi yapın 1,2,3"))
    if secim == 1:
        kisa_kenar = float(input("Kısa kenar : "))
        uzun_kenar = float(input("Uzun kenar : "))
        alan = dikdortgen_alani(kisa_kenar,uzun_kenar)
        print(alan)
def dikdortgen_alani(kisa_kenar,uzun_kenar):
    #Bu fonksiyon dikdortgenin alanını hesaplar
    return kisa_kenar*uzun_kenar
def dikdortgen_cevresi(kisa_kenar,uzun_kenar):
    pass
def dairenin_alani(r):
    alan = math.pi * (r ** 2)
    return alan 
def dairenin_cevresi(r):
    pass
def kare_alani(kenar):
    pass
def kare_cevresi(kenar):
    pass
